# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanyadarekar/Querying-the-derived-16-csv/blob/main/WTA_DF_STATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# You need the files from derived 16 attributes repository and a T_WTA_Elo file

import pandas as pd
# y2021=pd.read_csv("/content/T_ATP_2021_65.csv")
# yp2=pd.read_csv("/content/T_ATP_past2_65.csv")

y2021=pd.read_csv("/content/T_WTA_2021_65.csv")
yp2=pd.read_csv("/content/T_WTA_past2_65.csv")

# y2021=pd.read_csv("/content/T_ATP_CHQ_2021_65.csv")
# yp2=pd.read_csv("/content/T_CHQ_past2_65.csv")

# W_elo_June15 = pd.read_csv("/content/T_WTA_Elo.csv", encoding= 'unicode_escape')

# W_elo_June15.Player[1]

# %%
# Player 1
x="Iga Swiatek"
# Player 2
y="Naomi Osaka"
# Surface of Court : Hard/Clay/Grass
s="Hard"
p1=x.replace(" ", "")
p2=y.replace(" ", "")
# e1=x.replace(" ", "\xa0")
# e2=y.replace(" ", "\xa0")

# %%
# print("http://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="+p1)

# %%
# print("http://www.tennisabstract.com/cgi-bin/wplayer-classic.cgi?p="+p2)

# %%
# W_elo_June15.columns[-1]

# %%
#  W_elo_June15.query('Player=="{}"'.format(p1))[['Player','Age','Peak Age','Rank','Elo','Peak Elo','HardRaw','ClayRaw','GrassRaw',]]

# %%
# W_elo_June15.query('Player=="{}"'.format(p2))[['Player','Age','Peak Age','Rank','Elo','Peak Elo','HardRaw','ClayRaw','GrassRaw',]]

# %%
y2021.columns
# Out:
# Index(['Unnamed: 0', 'tourney_id', 'tourney_name', 'surface', 'draw_size',
#        'tourney_level', 'tourney_date', 'match_num', 'winner_id',
#        'winner_seed', 'winner_entry', 'winner_name', 'winner_hand',
#        'winner_ht', 'winner_ioc', 'winner_age', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'score', 'best_of', 'round', 'minutes', 'w_ace', 'w_df',
#        'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon', 'w_SvGms', 'w_bpSaved',
#        'w_bpFaced', 'l_ace', 'l_df', 'l_svpt', 'l_1stIn', 'l_1stWon',
#        'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced', 'winner_rank',
#        'winner_rank_points', 'loser_rank', 'loser_rank_points', 'w_1st_In_prc',
#        'l_1st_In_prc', 'w_1stprc', 'l_1stprc', 'w_2ndprc', 'l_2ndprc',
#        'w_bpSavedprc', 'l_bpSavedprc', 'w_dr', 'l_dr', 'w1st_retprc',
#        'l1st_retprc', 'w2nd_retprc', 'l2nd_retprc', 'nos', 'comeback'],
#       dtype='object')

# %%
required=["tourney_name",'round','surface',"tourney_date","winner_name","loser_name","score","nos","comeback","w_dr","l_dr", 'w_1st_In_prc',"w_1stprc","w_2ndprc","w1st_retprc","w2nd_retprc",'w_bpFaced', 'w_bpSavedprc', 'l_1st_In_prc',"l_1stprc","l_2ndprc","l1st_retprc","l2nd_retprc", 'l_bpFaced','l_bpSavedprc','w_ace','l_ace']
required_l=["tourney_name",'round','surface',"tourney_date","winner_name","loser_name","score","nos","comeback","w_dr","l_dr",'w_bpFaced', 'w_bpSavedprc', 'l_1st_In_prc',"l_1stprc","l_2ndprc","l1st_retprc","l2nd_retprc", 'l_bpFaced','l_bpSavedprc','w_ace','l_ace']
required_w=["tourney_name",'round','surface',"tourney_date","winner_name","loser_name","score","nos","comeback","w_dr","l_dr", 'w_1st_In_prc',"w_1stprc","w_2ndprc","w1st_retprc","w2nd_retprc",'w_bpFaced', 'w_bpSavedprc', 'l_bpFaced','l_bpSavedprc','w_ace','l_ace']

# %%
print("{} WINS IN 2021 stats".format(x))
y2021.query('winner_name=="{}" '.format(x))[required_w]
# Out:
# Iga Swiatek WINS IN 2021 stats
#           tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 80    Gippsland Trophy   R32    Hard  ...          38.0   2.0   2.0
# 249    Australian Open  R128    Hard  ...          71.0   0.0   4.0
# 285    Australian Open   R64    Hard  ...          33.0   4.0   0.0
# 303    Australian Open   R32    Hard  ...          65.0   1.0   0.0
# 375           Adelaide     F    Hard  ...          33.0   4.0   5.0
# 376           Adelaide    SF    Hard  ...          62.0   1.0   2.0
# 378           Adelaide    QF    Hard  ...          17.0   0.0   2.0
# 383           Adelaide   R16    Hard  ...          33.0   4.0   0.0
# 392           Adelaide   R32    Hard  ...          44.0   4.0   0.0
# 483              Dubai   R32    Hard  ...          67.0   6.0   1.0
# 646              Miami   R64    Hard  ...          45.0   2.0   1.0
# 890             Madrid   R32    Clay  ...          68.0   0.0   1.0
# ...

# %%
print("{} LOSSES in 2021".format(x))
y2021.query('loser_name=="{}" '.format(x))[required_l]
# Out:
# Iga Swiatek LOSSES in 2021
#           tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 70    Gippsland Trophy   R16    Hard  ...          50.0   7.0   2.0
# 312    Australian Open   R16    Hard  ...          60.0   3.0   2.0
# 471              Dubai   R16    Hard  ...          29.0   3.0   1.0
# 624              Miami   R32    Hard  ...          71.0  10.0   5.0
# 881             Madrid   R16    Clay  ...           0.0   6.0   2.0
# 1206     Roland Garros    QF    Clay  ...          62.0   5.0   0.0
# 1360        Eastbourne   R16   Grass  ...          11.0   4.0   2.0
# 1497         Wimbledon   R16   Grass  ...           0.0   9.0   2.0
# 1732    Tokyo Olympics   R32    Hard  ...           NaN   NaN   NaN
# 1886        Cincinnati   R32    Hard  ...          57.0  10.0   1.0
# 2094           Us Open   R16    Hard  ...          78.0   5.0   6.0
# 2168           Ostrava    SF    Hard  ...           NaN   NaN   NaN
#
# [12 rows x 22 columns]

# %%
print("{} WINS IN PAST 2 Years on {} stats".format(x,s))
yp2.query('winner_name=="{}" and surface=="{}"'.format(x,s))[required_w]
# Out:
# Iga Swiatek WINS IN PAST 2 Years on Hard stats
#                     tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 293                     Toronto    R64    Hard  ...          50.0   0.0   0.0
# 317                     Toronto    R32    Hard  ...          40.0   4.0   3.0
# 1236                    Budapest   R32    Hard  ...          50.0   3.0   4.0
# 1726                     Us Open  R128    Hard  ...          29.0   5.0   1.0
# 1812             Australian Open  R128    Hard  ...          50.0  12.0   2.0
# 2517                  Cincinnati   R64    Hard  ...          17.0   8.0   2.0
# 2556                  Washington   R32    Hard  ...          57.0   2.0  10.0
# 2637   Fed Cup G1 RR: POL vs DEN    RR    Hard  ...          62.0   6.0   0.0
# 3010             Australian Open  R128    Hard  ...           0.0   3.0   0.0
# 3055             Australian Open   R64    Hard  ...          50.0   8.0   0.0
# ...

# %%
print("{} LOSSES in Past 2 years on {}".format(x,s))
yp2.query('loser_name=="{}" and surface=="{}"'.format(x,s))[required_l]
# Out:
# Iga Swiatek LOSSES in Past 2 years on Hard
#                    tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 332                    Toronto    R16    Hard  ...          57.0   9.0   4.0
# 1245                   Budapest   R16    Hard  ...          62.0   3.0   4.0
# 1763                    Us Open   R64    Hard  ...          62.0   3.0   1.0
# 1869            Australian Open   R64    Hard  ...          45.0   2.0   4.0
# 2533                 Cincinnati   R32    Hard  ...          33.0   5.0   3.0
# 2569                 Washington   R16    Hard  ...          40.0   6.0   2.0
# 2641  Fed Cup G1 RR: RUS vs POL    RR    Hard  ...          38.0   5.0   1.0
# 2656  Fed Cup G1 PM: POL vs UKR    RR    Hard  ...          64.0   9.0   4.0
# 3088            Australian Open   R16    Hard  ...          36.0   4.0   4.0
# 3241                       Doha   R32    Hard  ...          20.0   4.0   1.0
# 3477                 Cincinnati   R64    Hard  ...          25.0   2.0   2.0
# ...

# %%
print("{} WINS in 2021".format(y))

y2021.query('winner_name=="{}"'.format(y))[required_w]
# Out:
# Naomi Osaka WINS in 2021
#           tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 68    Gippsland Trophy    QF    Hard  ...          33.0   7.0   1.0
# 76    Gippsland Trophy   R16    Hard  ...          58.0   5.0   4.0
# 91    Gippsland Trophy   R32    Hard  ...           0.0   6.0   0.0
# 240    Australian Open  R128    Hard  ...          29.0   2.0   1.0
# 280    Australian Open   R64    Hard  ...          57.0  10.0   6.0
# 300    Australian Open   R32    Hard  ...          43.0   8.0   5.0
# 310    Australian Open   R16    Hard  ...          64.0  11.0   8.0
# 315    Australian Open    QF    Hard  ...          67.0   7.0   0.0
# 318    Australian Open    SF    Hard  ...           0.0   6.0   3.0
# 319    Australian Open     F    Hard  ...          20.0   6.0   2.0
# 618              Miami   R16    Hard  ...          64.0   3.0   0.0
# 634              Miami   R32    Hard  ...           NaN   NaN   NaN
# ...

# %%
print("{} 2021 LOSSES".format(y))
y2021.query('loser_name=="{}" '.format(y))[required_l]
# Out:
# Naomi Osaka 2021 LOSSES
#           tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 64    Gippsland Trophy    SF    Hard  ...           NaN   0.0   0.0
# 610              Miami    QF    Hard  ...          67.0   2.0   1.0
# 904             Madrid   R32    Clay  ...          50.0   5.0   5.0
# 967               Rome   R32    Clay  ...          20.0   4.0   4.0
# 1180     Roland Garros   R64    Clay  ...           NaN   NaN   NaN
# 1743    Tokyo Olympics   R16    Hard  ...           NaN   NaN   NaN
# 1878        Cincinnati   R16    Hard  ...          50.0   8.0   6.0
# 2088           Us Open   R32    Hard  ...          60.0   6.0  15.0
#
# [8 rows x 22 columns]

# %%
print("{} WINS in past 2 years on {}".format(y,s))
yp2.query('winner_name=="{}" and surface=="{}"'.format(y,s))[required_w]
# Out:
# Naomi Osaka WINS in past 2 years on Hard
#          tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 316          Toronto    R32    Hard  ...          75.0   3.0   0.0
# 332          Toronto    R16    Hard  ...          57.0   9.0   4.0
# 347   Shenzhen Finals    RR    Hard  ...           NaN   NaN   NaN
# 745             Osaka   R16    Hard  ...          38.0  13.0   0.0
# 749             Osaka    QF    Hard  ...          14.0   6.0   0.0
# 751             Osaka    SF    Hard  ...          43.0   6.0   1.0
# 752             Osaka     F    Hard  ...          73.0   4.0   0.0
# 1672          Us Open  R128    Hard  ...          38.0   8.0   1.0
# 1736          Us Open   R64    Hard  ...          33.0   2.0   2.0
# 1768          Us Open   R32    Hard  ...          14.0   5.0   2.0
# 1815  Australian Open  R128    Hard  ...          50.0   6.0   0.0
# 1871  Australian Open   R64    Hard  ...          62.0   6.0   2.0
# ...

# %%
print("{} LOSSES in past 2 years on {}".format(y,s))
yp2.query('loser_name=="{}" and surface=="{}" '.format(y,s))[required_l]
# Out:
# Naomi Osaka LOSSES in past 2 years on Hard
#          tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 221             Dubai   R32    Hard  ...          30.0   4.0   1.0
# 340          Toronto     QF    Hard  ...          60.0  12.0   0.0
# 1784          Us Open   R16    Hard  ...          57.0   0.0   9.0
# 2073     Indian Wells   R16    Hard  ...          38.0   4.0   1.0
# 2160            Miami   R32    Hard  ...          17.0   0.0   4.0
# 2429         Brisbane    SF    Hard  ...          50.0   6.0   8.0
# 2543       Cincinnati    QF    Hard  ...          71.0   2.0  10.0
# 2854         Brisbane    SF    Hard  ...          67.0  15.0  16.0
# 3072  Australian Open   R32    Hard  ...          25.0   1.0   5.0
# 3427       Cincinnati     F    Hard  ...           NaN   0.0   0.0
#
# [10 rows x 22 columns]

# %%
print("H2H past 2 Winner {}".format(y))
yp2.query('loser_name=="{}" and winner_name=="{}" '.format(x,y))[required]
# Out:
# H2H past 2 Winner Naomi Osaka
#     tourney_name round surface  ...  l_bpSavedprc w_ace l_ace
# 332     Toronto    R16    Hard  ...          57.0   9.0   4.0
#
# [1 rows x 27 columns]

# %%
print("H2H past 2 Winner {}".format(x))
yp2.query('loser_name=="{}" and winner_name=="{}" '.format(y,x))[required]
# Out:
# H2H past 2 Winner Iga Swiatek
# Empty DataFrame
# Columns: [tourney_name, round, surface, tourney_date, winner_name, loser_name, score, nos, comeback, w_dr, l_dr, w_1st_In_prc, w_1stprc, w_2ndprc, w1st_retprc, w2nd_retprc, w_bpFaced, w_bpSavedprc, l_1st_In_prc, l_1stprc, l_2ndprc, l1st_retprc, l2nd_retprc, l_bpFaced, l_bpSavedprc, w_ace, l_ace]
# Index: []

# %%
print("Head to Head 2021 Winner {}".format(y))
y2021.query('loser_name=="{}" and winner_name=="{}" '.format(x,y))[required]
# Out:
# Head to Head 2021 Winner Naomi Osaka
# Empty DataFrame
# Columns: [tourney_name, round, surface, tourney_date, winner_name, loser_name, score, nos, comeback, w_dr, l_dr, w_1st_In_prc, w_1stprc, w_2ndprc, w1st_retprc, w2nd_retprc, w_bpFaced, w_bpSavedprc, l_1st_In_prc, l_1stprc, l_2ndprc, l1st_retprc, l2nd_retprc, l_bpFaced, l_bpSavedprc, w_ace, l_ace]
# Index: []

# %%
print("Head to Head 2021 Winner {}".format(x))
y2021.query('loser_name=="{}" and winner_name=="{}" '.format(y,x))[required]
# Out:
# Head to Head 2021 Winner Iga Swiatek
# Empty DataFrame
# Columns: [tourney_name, round, surface, tourney_date, winner_name, loser_name, score, nos, comeback, w_dr, l_dr, w_1st_In_prc, w_1stprc, w_2ndprc, w1st_retprc, w2nd_retprc, w_bpFaced, w_bpSavedprc, l_1st_In_prc, l_1stprc, l_2ndprc, l1st_retprc, l2nd_retprc, l_bpFaced, l_bpSavedprc, w_ace, l_ace]
# Index: []
